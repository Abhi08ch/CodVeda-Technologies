# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi08ch/CodVeda-Technologies/blob/main/L1_Task_2_Build_a_Simple_Linear_Regression_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LEVEL **1**

# %% [markdown]
# # **Task 2: Build a Simple Linear  Regression Model**

# %%
# 1. Import all reequired libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 2. Assign Column Names
column_names = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
    'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'
]

df = pd.read_csv("/content/4) house Prediction Data Set.csv", sep='\s+', header=None, names=column_names)

# %%
# 3. Prepare features and target
x = df.drop('MEDV', axis=1)
y = df['MEDV']

# %%
# 4. Split and scale data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
Scalar = StandardScaler()
x_train_scaled = Scalar.fit_transform(x_train)
x_test_scaled = Scalar.transform(x_test)

# %%
# 5. Train Linear Regression Model
lr = LinearRegression()
lr  = lr.fit(x_train_scaled, y_train)

# %%
# 6. Evaluate the model
y_pred = lr.predict(x_test_scaled)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f"R2 Score: {r2:.3f}")
print(f"Mean_squared_error: {mse:.3f}")
# Out:
# R2 Score: 0.669
# Mean_squared_error: 24.291

# %%
# 7. Interpret Coefficients
print("Intercept", lr.intercept_)
print("Coefficients", lr.coef_)
print("Features names", x.columns.tolist())
# Out:
# Intercept 22.796534653465343
# Coefficients [-1.00213533  0.69626862  0.27806485  0.7187384  -2.0223194   3.14523956
#  -0.17604788 -3.0819076   2.25140666 -1.76701378 -2.03775151  1.12956831
#  -3.61165842]
# Features names ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# %%
# 8. Visualizing the predicitons
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual House Prices (MEDV)')
plt.ylabel('Predicted House Prices (MEDV)')
plt.title('Actual vs Predicted House Prices')
plt.grid(True)
plt.show()
