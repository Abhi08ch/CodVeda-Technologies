# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi08ch/CodVeda-Technologies/blob/main/Task1_DataPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LEVEL 1**

# %% [markdown]
# # **Task 1: Data Preprocessing for Machine Learning**

# %%
# 1. Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. Load the dataset
df = pd.read_csv("/content/1) iris.csv")
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 3. Check for missing values
print("\n Missing values in the dataset:")
print(df.isnull().sum())
# Out:
#  Missing values in the dataset:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# 4. Encode the categorical target variable ('species')
le = LabelEncoder()
df['species_encoded'] = le.fit_transform(df['species'])
print("\nLabel encoding mapping:")
for i, label in enumerate(le.classes_):
  print(f"{label}: {i}")
# Out:
# Label encoding mapping:
# setosa: 0
# versicolor: 1
# virginica: 2

# %%
# 5. Separate features and target
x = df.drop(['species', 'species_encoded'], axis=1)
y = df['species_encoded']

# %%
# 6. Split into train and test sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42, stratify=y)
print(f"\nTraining samples: {x_train.shape[0]}, Test samples: {x_test.shape[0]}")
# Out:
# Training samples: 120, Test samples: 30

# %%
# 7. Normalize/Standardize numerical features
scalar = StandardScaler()
x_train_scaled = scalar.fit_transform(x_train)
x_test_scaled = scalar.transform(x_test)

# %%
# 8. Output: Show processed data shapes
print("\nProcessed training feature shape: ", x_train_scaled.shape)
print("Processed test feature shape: ", x_test_scaled.shape)
print("Training feature shape", y_train.shape)
print("Test feature shape", y_test.shape)
# Out:
# Processed training feature shape:  (120, 4)
# Processed test feature shape:  (30, 4)
# Training feature shape (120,)
# Test feature shape (30,)

# %%
# 9. Drop the target column for feature visualization
X = df.drop('species', axis=1)

# %%
# 10. --- Boxplot before scaling ---
plt.figure(figsize=(12, 6))
sns.boxplot(data=X)
plt.title('Boxplot of Iris Features Before Scaling')
plt.show()

# %%
# 11. --- Scale the features ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# %%
# 12. --- Boxplot after scaling ---
plt.figure(figsize=(12, 6))
sns.boxplot(data=X_scaled_df)
plt.title('Boxplot of Iris Features After Scaling')
plt.show()
